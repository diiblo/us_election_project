# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# Configuration de la SparkSession pour se connecter au cluster
spark = SparkSession.builder \
    .master("spark://pyspark-master:7077") \
    .appName("MySparkApp") \
    .config("spark.executor.memory", "1g") \
    .config("spark.jars", "/usr/local/spark/jars/postgresql-42.6.0.jar") \
    .getOrCreate()

# %%
import pandas as pd
from sqlalchemy import create_engine
# Charger la table PostgreSQL dans PySpark
df_election = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://pg-ds-dellstore:5432/us_election_db") \
    .option("dbtable", "election_data") \
    .option("user", "postgres") \
    .option("password", "postgres") \
    .load()

# Filtrer les IDs pairs pour le traitement batch
df_batch = df_election.filter(F.col("id") % 2 == 0)

# Paramètres de connexion PostgreSQL
user = "postgres"
password = "postgres"
host = "pg-ds-dellstore"
port = "5432"
database = "us_election_db"

# Créer un moteur SQLAlchemy pour PostgreSQL
engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')

# 1. Charger les données PostgreSQL dans un DataFrame
query = "SELECT * FROM election_data WHERE MOD(id, 2) != 0;"  # Filtrer les IDs impairs directement dans la requête
df = pd.read_sql_query(query, engine)

# 2. Sauvegarder les données en CSV
csv_file = "/tmp/election_stream.csv"
df.to_csv(csv_file, index=False)
print(f"Fichier CSV généré : {csv_file}")
# Affichage des résultats pour vérifier
#df_batch.show()

#df_election.show()  # Vérifier que les données sont bien chargées
# Out:
# Fichier CSV généré : /tmp/election_stream.csv

# %%
# Afficher les données pour vérifier le chargement
#df_election.show()

# 1. Ajouter une colonne "score_difference" au niveau des comtés
df_with_diff = df_batch.withColumn(
    "score_difference",
    F.abs(F.col("Trump") - F.col("Harris"))
)

# 2. Agréger les scores par État
df_state_aggregation = df_with_diff.groupBy("State").agg(
    F.sum("Trump").alias("total_trump"),
    F.sum("Harris").alias("total_harris")
)

# 3. Déterminer le candidat gagnant par État
df_state_with_leader = df_state_aggregation.withColumn(
    "leading_candidate",
    F.when(F.col("total_trump") > F.col("total_harris"), "Trump").otherwise("Harris")
)

# 4. Joindre les données agrégées par État au DataFrame initial
df_final = df_with_diff.join(
    df_state_with_leader,
    on="State",
    how="left"
)

# Vérification des données finales
#df_final.select(
#    "State", "County", "Trump", "Harris", 
#    "score_difference", "total_trump", 
#    "total_harris", "leading_candidate"
#).show()

#df_final.select(
#    "id", "County"
#).show()

# 5. Sauvegarder les données enrichies dans PostgreSQL
df_final.write \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://pg-ds-dellstore:5432/us_election_db") \
    .option("dbtable", "public.election_data_enriched") \
    .option("user", "postgres") \
    .option("password", "postgres") \
    .option("driver", "org.postgresql.Driver") \
    .mode("overwrite") \
    .save()

# %%
from kafka import KafkaProducer
import time
import csv
import json

producer = KafkaProducer(
    bootstrap_servers=['kafka:29092'],
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# Lecture du fichier CSV
with open('/tmp/election_stream.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        # Envoi de chaque ligne à Kafka
        producer.send('election_stream', row)  # Envoi au topic Kafka
        print(f"Envoyé : {row}")
        time.sleep(2)  # Pause pour simuler un flux continu
# Out:
# Envoyé : {'id': '1', 'state': 'Alabama', 'county': 'Autauga', 'trump': '72.4', 'harris': '26.3'}
# Envoyé : {'id': '3', 'state': 'Alabama', 'county': 'Barbour', 'trump': '56.9', 'harris': '42.2'}
# Envoyé : {'id': '5', 'state': 'Alabama', 'county': 'Blount', 'trump': '90.0', 'harris': '9.1'}
# Envoyé : {'id': '7', 'state': 'Alabama', 'county': 'Butler', 'trump': '61.0', 'harris': '38.3'}
# Envoyé : {'id': '9', 'state': 'Alabama', 'county': 'Chambers', 'trump': '61.2', 'harris': '37.9'}
# Envoyé : {'id': '11', 'state': 'Alabama', 'county': 'Chilton', 'trump': '85.6', 'harris': '13.7'}
# Envoyé : {'id': '13', 'state': 'Alabama', 'county': 'Clarke', 'trump': '58.2', 'harris': '41.2'}
# Envoyé : {'id': '15', 'state': 'Alabama', 'county': 'Cleburne', 'trump': '91.3', 'harris': '7.9'}
# Envoyé : {'id': '17', 'state': 'Alabama', 'county': 'Colbert', 'trump': '72.6', 'harris': '26.3'}
# Envoyé : {'id': '19', 'state': 'Alabama', 'county': 'Coosa', 'trump': '71.3', 'harris': '28.1'}
# Envoyé : {'id': '21', 'state': 'Alabama', 'county': 'Crenshaw', 'trump': '77.1', 'harris': '22.5'}
# Envoyé : {'id': '23', 'state': 'Alabama', 'county': 'Dale', 'trump': '75.6', 'harris': '23.4'}
# Envoyé : {'id': '25', 'state': 'Alabama', 'county': 'DeKalb', 'trump': '86.4', 'harris': '12.7'}
# Envoyé : {'id': '27', 'state': 'Alabama', 'county': 'Escambia', 'trump': '72.8', 'harris': '26.5'}
# Envoyé : {'id': '29', 'state': 'Alabama', 'county': 'Fayette', 'trump': '85.5', 'harris': '13.6'}
# Envoyé : {'id': '31', 'state': 'Alabama', 'county': 'Geneva', 'trump': '88.1', 'harris': '11.2'}
# Envoyé : {'id': '33', 'state': 'Alabama', 'county': 'Hale', 'trump': '46.1', 'harris': '53.0'}
# Envoyé : {'id': '35', 'state': 'Alabama', 'county': 'Houston', 'trump': '73.2', 'harris': '25.6'}
# Envoyé : {'id': '37', 'state': 'Alabama', 'county': 'Jefferson', 'trump': '43.9', 'harris': '54.3'}
# Envoyé : {'id': '39', 'state': 'Alabama', 'county': 'Lauderdale', 'trump': '75.0', 'harris': '23.7'}
# Envoyé : {'id': '41', 'state': 'Alabama', 'county': 'Lee', 'trump': '62.9', 'harris': '35.3'}
# Envoyé : {'id': '43', 'state': 'Alabama', 'county': 'Lowndes', 'trump': '31.1', 'harris': '68.4'}
# Envoyé : {'id': '45', 'state': 'Alabama', 'county': 'Madison', 'trump': '53.4', 'harris': '44.4'}
# Envoyé : {'id': '47', 'state': 'Alabama', 'county': 'Marion', 'trump': '90.4', 'harris': '8.8'}
# Envoyé : {'id': '49', 'state': 'Alabama', 'county': 'Mobile', 'trump': '57.5', 'harris': '41.1'}
# Envoyé : {'id': '51', 'state': 'Alabama', 'county': 'Montgomery', 'trump': '33.9', 'harris': '64.5'}
# Envoyé : {'id': '53', 'state': 'Alabama', 'county': 'Perry', 'trump': '28.4', 'harris': '71.1'}
# Envoyé : {'id': '55', 'state': 'Alabama', 'county': 'Pike', 'trump': '62.1', 'harris': '37.0'}
# Envoyé : {'id': '57', 'state': 'Alabama', 'county': 'Russell', 'trump': '48.6', 'harris': '50.3'}
# Envoyé : {'id': '59', 'state': 'Alabama', 'county': 'St. Clair', 'trump': '81.6', 'harris': '17.6'}
# Envoyé : {'id': '61', 'state': 'Alabama', 'county': 'Talladega', 'trump': '66.3', 'harris': '33.0'}
# Envoyé : {'id': '63', 'state': 'Alabama', 'county': 'Tuscaloosa', 'trump': '59.5', 'harris': '39.2'}
# Envoyé : {'id': '65', 'state': 'Alabama', 'county': 'Washington', 'trump': '77.4', 'harris': '22.1'}
# Envoyé : {'id': '67', 'state': 'Alabama', 'county': 'Winston', 'trump': '91.4', 'harris': '7.9'}
# Envoyé : {'id': '69', 'state': 'Alaska', 'county': 'ED02 Central/North Panhandle', 'trump': '47.5', 'harris': '47.7'}
# Envoyé : {'id': '71', 'state': 'Alaska', 'county': 'ED04 Greater Juneau', 'trump': '29.1', 'harris': '66.4'}
# Envoyé : {'id': '73', 'state': 'Alaska', 'county': 'ED06 South Kenai Peninsula', 'trump': '55.3', 'harris': '40.3'}
# Envoyé : {'id': '75', 'state': 'Alaska', 'county': 'ED08 North/East Kenai Penin.', 'trump': '73.5', 'harris': '23.9'}
# Envoyé : {'id': '77', 'state': 'Alaska', 'county': 'ED10 S-Central Anch Suburbs', 'trump': '50.2', 'harris': '46.1'}
# Envoyé : {'id': '79', 'state': 'Alaska', 'county': 'ED12 S-Central Anch Suburbs', 'trump': '48.0', 'harris': '48.7'}
# Envoyé : {'id': '81', 'state': 'Alaska', 'county': 'ED14 Midtown Anchorage', 'trump': '37.5', 'harris': '58.4'}
# Envoyé : {'id': '83', 'state': 'Alaska', 'county': 'ED16 West Anchorage Suburbs', 'trump': '40.8', 'harris': '55.1'}
# Envoyé : {'id': '85', 'state': 'Alaska', 'county': 'ED18 NE Anchorage City', 'trump': '56.0', 'harris': '39.9'}
# Envoyé : {'id': '87', 'state': 'Alaska', 'county': 'ED20 E-Central Anch City', 'trump': '41.9', 'harris': '53.9'}
# Envoyé : {'id': '89', 'state': 'Alaska', 'county': 'ED22 NE Anchorage City', 'trump': '48.0', 'harris': '48.3'}
# Envoyé : {'id': '91', 'state': 'Alaska', 'county': 'ED24 FarNorth Anchorage Boro', 'trump': '64.3', 'harris': '31.8'}
# Envoyé : {'id': '93', 'state': 'Alaska', 'county': 'ED26 Mat-Su Valley South', 'trump': '75.6', 'harris': '21.3'}
# Envoyé : {'id': '95', 'state': 'Alaska', 'county': 'ED28 Mat-Su - East Wasilla', 'trump': '72.2', 'harris': '24.0'}
# Envoyé : {'id': '97', 'state': 'Alaska', 'county': 'ED30 Mat-Su - Parks Highway', 'trump': '70.8', 'harris': '26.4'}
# Envoyé : {'id': '99', 'state': 'Alaska', 'county': 'ED32 East Fairbanks', 'trump': '63.8', 'harris': '32.1'}
# Envoyé : {'id': '101', 'state': 'Alaska', 'county': 'ED34 E. Fairbanks Outskirts', 'trump': '58.3', 'harris': '37.5'}
# Envoyé : {'id': '103', 'state': 'Alaska', 'county': 'ED36 Interior Alaska', 'trump': '58.8', 'harris': '36.8'}
# Envoyé : {'id': '105', 'state': 'Alaska', 'county': 'ED38 Bering Coast', 'trump': '37.0', 'harris': '50.6'}
# Envoyé : {'id': '107', 'state': 'Alaska', 'county': 'ED40 Arctic', 'trump': '50.2', 'harris': '42.2'}
# Envoyé : {'id': '109', 'state': 'Arizona', 'county': 'Cochise', 'trump': '61.0', 'harris': '37.8'}
# Envoyé : {'id': '111', 'state': 'Arizona', 'county': 'Gila', 'trump': '68.4', 'harris': '30.8'}
# Envoyé : {'id': '113', 'state': 'Arizona', 'county': 'Greenlee', 'trump': '69.8', 'harris': '28.8'}
# Envoyé : {'id': '115', 'state': 'Arizona', 'county': 'Maricopa', 'trump': '51.2', 'harris': '47.7'}
# Envoyé : {'id': '117', 'state': 'Arizona', 'county': 'Navajo', 'trump': '58.1', 'harris': '40.9'}
# Envoyé : {'id': '119', 'state': 'Arizona', 'county': 'Pinal', 'trump': '60.6', 'harris': '38.5'}
# Envoyé : {'id': '121', 'state': 'Arizona', 'county': 'Yavapai', 'trump': '66.5', 'harris': '32.6'}
# Envoyé : {'id': '123', 'state': 'Arkansas', 'county': 'Arkansas County', 'trump': '71.2', 'harris': '27.1'}
# Envoyé : {'id': '125', 'state': 'Arkansas', 'county': 'Baxter', 'trump': '77.6', 'harris': '20.7'}
# Envoyé : {'id': '127', 'state': 'Arkansas', 'county': 'Boone', 'trump': '81.6', 'harris': '16.7'}
# Envoyé : {'id': '129', 'state': 'Arkansas', 'county': 'Calhoun', 'trump': '80.0', 'harris': '18.1'}
# Envoyé : {'id': '131', 'state': 'Arkansas', 'county': 'Chicot', 'trump': '47.5', 'harris': '51.5'}
# Envoyé : {'id': '133', 'state': 'Arkansas', 'county': 'Clay', 'trump': '79.9', 'harris': '18.3'}
# Envoyé : {'id': '135', 'state': 'Arkansas', 'county': 'Cleveland', 'trump': '83.1', 'harris': '15.5'}
# Envoyé : {'id': '137', 'state': 'Arkansas', 'county': 'Conway', 'trump': '69.0', 'harris': '28.7'}
# Envoyé : {'id': '139', 'state': 'Arkansas', 'county': 'Crawford', 'trump': '78.1', 'harris': '19.9'}
# Envoyé : {'id': '141', 'state': 'Arkansas', 'county': 'Cross', 'trump': '72.7', 'harris': '25.1'}
# Envoyé : {'id': '143', 'state': 'Arkansas', 'county': 'Desha', 'trump': '51.5', 'harris': '46.7'}
# Envoyé : {'id': '145', 'state': 'Arkansas', 'county': 'Faulkner', 'trump': '64.9', 'harris': '32.6'}
# Envoyé : {'id': '147', 'state': 'Arkansas', 'county': 'Fulton', 'trump': '80.1', 'harris': '18.0'}
# Envoyé : {'id': '149', 'state': 'Arkansas', 'county': 'Grant', 'trump': '83.6', 'harris': '14.8'}
# Envoyé : {'id': '151', 'state': 'Arkansas', 'county': 'Hempstead', 'trump': '68.9', 'harris': '29.2'}
# Envoyé : {'id': '153', 'state': 'Arkansas', 'county': 'Howard', 'trump': '72.6', 'harris': '25.9'}
# Envoyé : {'id': '155', 'state': 'Arkansas', 'county': 'Izard', 'trump': '81.9', 'harris': '16.0'}
# Envoyé : {'id': '157', 'state': 'Arkansas', 'county': 'Jefferson', 'trump': '39.2', 'harris': '59.2'}
# Envoyé : {'id': '159', 'state': 'Arkansas', 'county': 'Lafayette', 'trump': '68.3', 'harris': '30.0'}
# Envoyé : {'id': '161', 'state': 'Arkansas', 'county': 'Lee', 'trump': '46.9', 'harris': '50.4'}
# Envoyé : {'id': '163', 'state': 'Arkansas', 'county': 'Little River', 'trump': '76.4', 'harris': '22.1'}
# Envoyé : {'id': '165', 'state': 'Arkansas', 'county': 'Lonoke', 'trump': '75.8', 'harris': '22.2'}
# Envoyé : {'id': '167', 'state': 'Arkansas', 'county': 'Marion', 'trump': '79.4', 'harris': '19.1'}
# Envoyé : {'id': '169', 'state': 'Arkansas', 'county': 'Mississippi', 'trump': '65.0', 'harris': '33.3'}
# Envoyé : {'id': '171', 'state': 'Arkansas', 'county': 'Montgomery', 'trump': '80.6', 'harris': '17.4'}
# Envoyé : {'id': '173', 'state': 'Arkansas', 'county': 'Newton', 'trump': '81.2', 'harris': '17.1'}
# Envoyé : {'id': '175', 'state': 'Arkansas', 'county': 'Perry', 'trump': '77.6', 'harris': '20.1'}
# Envoyé : {'id': '177', 'state': 'Arkansas', 'county': 'Pike', 'trump': '86.0', 'harris': '12.8'}
# Envoyé : {'id': '179', 'state': 'Arkansas', 'county': 'Polk', 'trump': '84.3', 'harris': '13.8'}
# Envoyé : {'id': '181', 'state': 'Arkansas', 'county': 'Prairie', 'trump': '82.1', 'harris': '16.4'}
# Envoyé : {'id': '183', 'state': 'Arkansas', 'county': 'Randolph', 'trump': '80.9', 'harris': '17.1'}
# Envoyé : {'id': '185', 'state': 'Arkansas', 'county': 'Scott', 'trump': '86.1', 'harris': '12.6'}
# Envoyé : {'id': '187', 'state': 'Arkansas', 'county': 'Sebastian', 'trump': '67.6', 'harris': '30.0'}
# Envoyé : {'id': '189', 'state': 'Arkansas', 'county': 'Sharp', 'trump': '80.4', 'harris': '17.7'}
# Envoyé : {'id': '191', 'state': 'Arkansas', 'county': 'Stone', 'trump': '79.7', 'harris': '18.1'}
# Envoyé : {'id': '193', 'state': 'Arkansas', 'county': 'Van Buren', 'trump': '79.0', 'harris': '18.9'}
# Envoyé : {'id': '195', 'state': 'Arkansas', 'county': 'White', 'trump': '79.5', 'harris': '18.3'}
# Envoyé : {'id': '197', 'state': 'Arkansas', 'county': 'Yell', 'trump': '79.5', 'harris': '18.7'}
# Envoyé : {'id': '199', 'state': 'California', 'county': 'Alpine', 'trump': '32.9', 'harris': '64.9'}
# Envoyé : {'id': '201', 'state': 'California', 'county': 'Butte', 'trump': '49.9', 'harris': '46.8'}
# Envoyé : {'id': '203', 'state': 'California', 'county': 'Colusa', 'trump': '62.9', 'harris': '34.6'}
# Envoyé : {'id': '205', 'state': 'California', 'county': 'Del Norte', 'trump': '56.8', 'harris': '40.4'}
# Envoyé : {'id': '207', 'state': 'California', 'county': 'Fresno', 'trump': '51.0', 'harris': '46.5'}
# Envoyé : {'id': '209', 'state': 'California', 'county': 'Humboldt', 'trump': '33.5', 'harris': '62.0'}
# Envoyé : {'id': '211', 'state': 'California', 'county': 'Inyo', 'trump': '49.9', 'harris': '46.9'}
# Envoyé : {'id': '213', 'state': 'California', 'county': 'Kings', 'trump': '60.4', 'harris': '37.4'}
# Envoyé : {'id': '215', 'state': 'California', 'county': 'Lassen', 'trump': '75.7', 'harris': '21.9'}
# Envoyé : {'id': '217', 'state': 'California', 'county': 'Madera', 'trump': '59.2', 'harris': '38.4'}
# Envoyé : {'id': '219', 'state': 'California', 'county': 'Mariposa', 'trump': '59.2', 'harris': '38.1'}
# Envoyé : {'id': '221', 'state': 'California', 'county': 'Merced', 'trump': '50.8', 'harris': '46.6'}
# Envoyé : {'id': '223', 'state': 'California', 'county': 'Mono', 'trump': '37.8', 'harris': '58.1'}
# Envoyé : {'id': '225', 'state': 'California', 'county': 'Napa', 'trump': '31.1', 'harris': '65.9'}
# Envoyé : {'id': '227', 'state': 'California', 'county': 'Orange', 'trump': '47.1', 'harris': '49.7'}
# Envoyé : {'id': '229', 'state': 'California', 'county': 'Plumas', 'trump': '56.9', 'harris': '39.9'}
# Envoyé : {'id': '231', 'state': 'California', 'county': 'Sacramento', 'trump': '38.3', 'harris': '58.2'}
# Envoyé : {'id': '233', 'state': 'California', 'county': 'San Bernardino', 'trump': '49.7', 'harris': '47.5'}
# Envoyé : {'id': '235', 'state': 'California', 'county': 'San Francisco', 'trump': '15.5', 'harris': '80.3'}
# Envoyé : {'id': '237', 'state': 'California', 'county': 'San Luis Obispo', 'trump': '43.1', 'harris': '53.9'}
# Envoyé : {'id': '239', 'state': 'California', 'county': 'Santa Barbara', 'trump': '35.1', 'harris': '61.8'}
# Envoyé : {'id': '241', 'state': 'California', 'county': 'Santa Cruz', 'trump': '20.9', 'harris': '75.2'}
# Envoyé : {'id': '243', 'state': 'California', 'county': 'Sierra', 'trump': '60.8', 'harris': '36.5'}
# Envoyé : {'id': '245', 'state': 'California', 'county': 'Solano', 'trump': '37.1', 'harris': '60.0'}
# Envoyé : {'id': '247', 'state': 'California', 'county': 'Stanislaus', 'trump': '54.2', 'harris': '43.2'}
# Envoyé : {'id': '249', 'state': 'California', 'county': 'Tehama', 'trump': '69.7', 'harris': '28.0'}
# Envoyé : {'id': '251', 'state': 'California', 'county': 'Tulare', 'trump': '59.2', 'harris': '38.5'}
# Envoyé : {'id': '253', 'state': 'California', 'county': 'Ventura', 'trump': '41.0', 'harris': '56.1'}
# Envoyé : {'id': '255', 'state': 'California', 'county': 'Yuba', 'trump': '61.5', 'harris': '35.7'}
# Envoyé : {'id': '257', 'state': 'Colorado', 'county': 'Alamosa', 'trump': '54.0', 'harris': '43.1'}
# Envoyé : {'id': '259', 'state': 'Colorado', 'county': 'Archuleta', 'trump': '55.8', 'harris': '41.7'}
# Envoyé : {'id': '261', 'state': 'Colorado', 'county': 'Bent', 'trump': '68.3', 'harris': '29.5'}
# Envoyé : {'id': '263', 'state': 'Colorado', 'county': 'Broomfield', 'trump': '34.3', 'harris': '62.9'}
# Envoyé : {'id': '265', 'state': 'Colorado', 'county': 'Cheyenne', 'trump': '88.2', 'harris': '10.2'}
# Envoyé : {'id': '267', 'state': 'Colorado', 'county': 'Conejos', 'trump': '57.5', 'harris': '39.6'}
# Envoyé : {'id': '269', 'state': 'Colorado', 'county': 'Crowley', 'trump': '72.2', 'harris': '24.7'}
# Envoyé : {'id': '271', 'state': 'Colorado', 'county': 'Delta', 'trump': '66.5', 'harris': '31.0'}
# Envoyé : {'id': '273', 'state': 'Colorado', 'county': 'Dolores', 'trump': '75.8', 'harris': '22.9'}
# Envoyé : {'id': '275', 'state': 'Colorado', 'county': 'Eagle', 'trump': '36.5', 'harris': '61.0'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 18
#      16 producer.send('election_stream', row)  # Envoi au topic Kafka
#      17 print(f"Envoyé : {row}")
# ---> 18 time.sleep(2)  # Pause pour simuler un flux continu
#
# KeyboardInterrupt:
