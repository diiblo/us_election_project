# %%
from kafka import KafkaConsumer
import psycopg2
import json

# Configurer le consommateur Kafka
consumer = KafkaConsumer(
    'election_stream',
    bootstrap_servers=['kafka:29092'],
    auto_offset_reset='earliest',
    enable_auto_commit=True,
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# Connexion à la base PostgreSQL
conn = psycopg2.connect(
    database="us_election_db",
    user="postgres",
    password="postgres",
    host="pg-ds-dellstore",
    port="5432"
)
cursor = conn.cursor()

# Stocker les données agrégées en mémoire pour mise à jour
state_aggregation = {}

# Traitement des messages reçus
for message in consumer:
    data = message.value
    print(f"Reçu : {data}")
    
    # Calculer la différence de score
    score_difference = abs(float(data['trump']) - float(data['harris']))
    
    # Mettre à jour l'agrégation des scores par État
    state = data['state']
    if state not in state_aggregation:
        state_aggregation[state] = {"total_trump": 0, "total_harris": 0}
    
    state_aggregation[state]["total_trump"] += float(data['trump'])
    state_aggregation[state]["total_harris"] += float(data['harris'])
    
    # Déterminer le candidat en tête pour l'État
    leading_candidate = (
        "trump" 
        if state_aggregation[state]["total_trump"] > state_aggregation[state]["total_harris"] 
        else "harris"
    )
    
    # Données transformées à insérer
    transformed_data = {
        'id': data['id'],
        'state': state,
        'county': data['county'],
        'trump': float(data['trump']),
        'harris': float(data['harris']),
        'score_difference': score_difference,
        'total_trump': state_aggregation[state]["total_trump"],
        'total_harris': state_aggregation[state]["total_harris"],
        'leading_candidate': leading_candidate
    }
    
    # Afficher les données transformées avant insertion
    print(f"Données transformées : {transformed_data}")
    
    # Préparer la requête d'insertion pour les données enrichies
    insert_query = """
        INSERT INTO election_data_enriched (
            id, state, county, trump, harris, score_difference, 
            total_trump, total_harris, leading_candidate
        )
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    
    # Exécution de la requête d'insertion
    cursor.execute(insert_query, (
        transformed_data['id'],  # ID unique du comté
        transformed_data['state'],  # État
        transformed_data['county'],  # Comté
        transformed_data['trump'],  # Score Trump
        transformed_data['harris'],  # Score Harris
        transformed_data['score_difference'],  # Différence de score
        transformed_data['total_trump'],  # Total Trump dans l'État
        transformed_data['total_harris'],  # Total Harris dans l'État
        transformed_data['leading_candidate']  # Candidat en tête dans l'État
    ))
    
    # Sauvegarder les modifications dans la base
    conn.commit()  # Sauvegarder les modifications dans la base

# Fermer la connexion à la base
cursor.close()
conn.close()
# Out:
# Reçu : {'id': '1', 'state': 'Alabama', 'county': 'Autauga', 'trump': '72.4', 'harris': '26.3'}
# Données transformées : {'id': '1', 'state': 'Alabama', 'county': 'Autauga', 'trump': 72.4, 'harris': 26.3, 'score_difference': 46.10000000000001, 'total_trump': 72.4, 'total_harris': 26.3, 'leading_candidate': 'trump'}
# Reçu : {'id': '3', 'state': 'Alabama', 'county': 'Barbour', 'trump': '56.9', 'harris': '42.2'}
# Données transformées : {'id': '3', 'state': 'Alabama', 'county': 'Barbour', 'trump': 56.9, 'harris': 42.2, 'score_difference': 14.699999999999996, 'total_trump': 129.3, 'total_harris': 68.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '5', 'state': 'Alabama', 'county': 'Blount', 'trump': '90.0', 'harris': '9.1'}
# Données transformées : {'id': '5', 'state': 'Alabama', 'county': 'Blount', 'trump': 90.0, 'harris': 9.1, 'score_difference': 80.9, 'total_trump': 219.3, 'total_harris': 77.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '7', 'state': 'Alabama', 'county': 'Butler', 'trump': '61.0', 'harris': '38.3'}
# Données transformées : {'id': '7', 'state': 'Alabama', 'county': 'Butler', 'trump': 61.0, 'harris': 38.3, 'score_difference': 22.700000000000003, 'total_trump': 280.3, 'total_harris': 115.89999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '9', 'state': 'Alabama', 'county': 'Chambers', 'trump': '61.2', 'harris': '37.9'}
# Données transformées : {'id': '9', 'state': 'Alabama', 'county': 'Chambers', 'trump': 61.2, 'harris': 37.9, 'score_difference': 23.300000000000004, 'total_trump': 341.5, 'total_harris': 153.79999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '11', 'state': 'Alabama', 'county': 'Chilton', 'trump': '85.6', 'harris': '13.7'}
# Données transformées : {'id': '11', 'state': 'Alabama', 'county': 'Chilton', 'trump': 85.6, 'harris': 13.7, 'score_difference': 71.89999999999999, 'total_trump': 427.1, 'total_harris': 167.49999999999997, 'leading_candidate': 'trump'}
# Reçu : {'id': '13', 'state': 'Alabama', 'county': 'Clarke', 'trump': '58.2', 'harris': '41.2'}
# Données transformées : {'id': '13', 'state': 'Alabama', 'county': 'Clarke', 'trump': 58.2, 'harris': 41.2, 'score_difference': 17.0, 'total_trump': 485.3, 'total_harris': 208.7, 'leading_candidate': 'trump'}
# Reçu : {'id': '15', 'state': 'Alabama', 'county': 'Cleburne', 'trump': '91.3', 'harris': '7.9'}
# Données transformées : {'id': '15', 'state': 'Alabama', 'county': 'Cleburne', 'trump': 91.3, 'harris': 7.9, 'score_difference': 83.39999999999999, 'total_trump': 576.6, 'total_harris': 216.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '17', 'state': 'Alabama', 'county': 'Colbert', 'trump': '72.6', 'harris': '26.3'}
# Données transformées : {'id': '17', 'state': 'Alabama', 'county': 'Colbert', 'trump': 72.6, 'harris': 26.3, 'score_difference': 46.3, 'total_trump': 649.2, 'total_harris': 242.9, 'leading_candidate': 'trump'}
# Reçu : {'id': '19', 'state': 'Alabama', 'county': 'Coosa', 'trump': '71.3', 'harris': '28.1'}
# Données transformées : {'id': '19', 'state': 'Alabama', 'county': 'Coosa', 'trump': 71.3, 'harris': 28.1, 'score_difference': 43.199999999999996, 'total_trump': 720.5, 'total_harris': 271.0, 'leading_candidate': 'trump'}
# Reçu : {'id': '21', 'state': 'Alabama', 'county': 'Crenshaw', 'trump': '77.1', 'harris': '22.5'}
# Données transformées : {'id': '21', 'state': 'Alabama', 'county': 'Crenshaw', 'trump': 77.1, 'harris': 22.5, 'score_difference': 54.599999999999994, 'total_trump': 797.6, 'total_harris': 293.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '23', 'state': 'Alabama', 'county': 'Dale', 'trump': '75.6', 'harris': '23.4'}
# Données transformées : {'id': '23', 'state': 'Alabama', 'county': 'Dale', 'trump': 75.6, 'harris': 23.4, 'score_difference': 52.199999999999996, 'total_trump': 873.2, 'total_harris': 316.9, 'leading_candidate': 'trump'}
# Reçu : {'id': '25', 'state': 'Alabama', 'county': 'DeKalb', 'trump': '86.4', 'harris': '12.7'}
# Données transformées : {'id': '25', 'state': 'Alabama', 'county': 'DeKalb', 'trump': 86.4, 'harris': 12.7, 'score_difference': 73.7, 'total_trump': 959.6, 'total_harris': 329.59999999999997, 'leading_candidate': 'trump'}
# Reçu : {'id': '27', 'state': 'Alabama', 'county': 'Escambia', 'trump': '72.8', 'harris': '26.5'}
# Données transformées : {'id': '27', 'state': 'Alabama', 'county': 'Escambia', 'trump': 72.8, 'harris': 26.5, 'score_difference': 46.3, 'total_trump': 1032.4, 'total_harris': 356.09999999999997, 'leading_candidate': 'trump'}
# Reçu : {'id': '29', 'state': 'Alabama', 'county': 'Fayette', 'trump': '85.5', 'harris': '13.6'}
# Données transformées : {'id': '29', 'state': 'Alabama', 'county': 'Fayette', 'trump': 85.5, 'harris': 13.6, 'score_difference': 71.9, 'total_trump': 1117.9, 'total_harris': 369.7, 'leading_candidate': 'trump'}
# Reçu : {'id': '31', 'state': 'Alabama', 'county': 'Geneva', 'trump': '88.1', 'harris': '11.2'}
# Données transformées : {'id': '31', 'state': 'Alabama', 'county': 'Geneva', 'trump': 88.1, 'harris': 11.2, 'score_difference': 76.89999999999999, 'total_trump': 1206.0, 'total_harris': 380.9, 'leading_candidate': 'trump'}
# Reçu : {'id': '33', 'state': 'Alabama', 'county': 'Hale', 'trump': '46.1', 'harris': '53.0'}
# Données transformées : {'id': '33', 'state': 'Alabama', 'county': 'Hale', 'trump': 46.1, 'harris': 53.0, 'score_difference': 6.899999999999999, 'total_trump': 1252.1, 'total_harris': 433.9, 'leading_candidate': 'trump'}
# Reçu : {'id': '35', 'state': 'Alabama', 'county': 'Houston', 'trump': '73.2', 'harris': '25.6'}
# Données transformées : {'id': '35', 'state': 'Alabama', 'county': 'Houston', 'trump': 73.2, 'harris': 25.6, 'score_difference': 47.6, 'total_trump': 1325.3, 'total_harris': 459.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '37', 'state': 'Alabama', 'county': 'Jefferson', 'trump': '43.9', 'harris': '54.3'}
# Données transformées : {'id': '37', 'state': 'Alabama', 'county': 'Jefferson', 'trump': 43.9, 'harris': 54.3, 'score_difference': 10.399999999999999, 'total_trump': 1369.2, 'total_harris': 513.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '39', 'state': 'Alabama', 'county': 'Lauderdale', 'trump': '75.0', 'harris': '23.7'}
# Données transformées : {'id': '39', 'state': 'Alabama', 'county': 'Lauderdale', 'trump': 75.0, 'harris': 23.7, 'score_difference': 51.3, 'total_trump': 1444.2, 'total_harris': 537.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '41', 'state': 'Alabama', 'county': 'Lee', 'trump': '62.9', 'harris': '35.3'}
# Données transformées : {'id': '41', 'state': 'Alabama', 'county': 'Lee', 'trump': 62.9, 'harris': 35.3, 'score_difference': 27.6, 'total_trump': 1507.1000000000001, 'total_harris': 572.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '43', 'state': 'Alabama', 'county': 'Lowndes', 'trump': '31.1', 'harris': '68.4'}
# Données transformées : {'id': '43', 'state': 'Alabama', 'county': 'Lowndes', 'trump': 31.1, 'harris': 68.4, 'score_difference': 37.300000000000004, 'total_trump': 1538.2, 'total_harris': 641.1999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '45', 'state': 'Alabama', 'county': 'Madison', 'trump': '53.4', 'harris': '44.4'}
# Données transformées : {'id': '45', 'state': 'Alabama', 'county': 'Madison', 'trump': 53.4, 'harris': 44.4, 'score_difference': 9.0, 'total_trump': 1591.6000000000001, 'total_harris': 685.5999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '47', 'state': 'Alabama', 'county': 'Marion', 'trump': '90.4', 'harris': '8.8'}
# Données transformées : {'id': '47', 'state': 'Alabama', 'county': 'Marion', 'trump': 90.4, 'harris': 8.8, 'score_difference': 81.60000000000001, 'total_trump': 1682.0000000000002, 'total_harris': 694.3999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '49', 'state': 'Alabama', 'county': 'Mobile', 'trump': '57.5', 'harris': '41.1'}
# Données transformées : {'id': '49', 'state': 'Alabama', 'county': 'Mobile', 'trump': 57.5, 'harris': 41.1, 'score_difference': 16.4, 'total_trump': 1739.5000000000002, 'total_harris': 735.4999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '51', 'state': 'Alabama', 'county': 'Montgomery', 'trump': '33.9', 'harris': '64.5'}
# Données transformées : {'id': '51', 'state': 'Alabama', 'county': 'Montgomery', 'trump': 33.9, 'harris': 64.5, 'score_difference': 30.6, 'total_trump': 1773.4000000000003, 'total_harris': 799.9999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '53', 'state': 'Alabama', 'county': 'Perry', 'trump': '28.4', 'harris': '71.1'}
# Données transformées : {'id': '53', 'state': 'Alabama', 'county': 'Perry', 'trump': 28.4, 'harris': 71.1, 'score_difference': 42.699999999999996, 'total_trump': 1801.8000000000004, 'total_harris': 871.0999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '55', 'state': 'Alabama', 'county': 'Pike', 'trump': '62.1', 'harris': '37.0'}
# Données transformées : {'id': '55', 'state': 'Alabama', 'county': 'Pike', 'trump': 62.1, 'harris': 37.0, 'score_difference': 25.1, 'total_trump': 1863.9000000000003, 'total_harris': 908.0999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '57', 'state': 'Alabama', 'county': 'Russell', 'trump': '48.6', 'harris': '50.3'}
# Données transformées : {'id': '57', 'state': 'Alabama', 'county': 'Russell', 'trump': 48.6, 'harris': 50.3, 'score_difference': 1.6999999999999957, 'total_trump': 1912.5000000000002, 'total_harris': 958.3999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '59', 'state': 'Alabama', 'county': 'St. Clair', 'trump': '81.6', 'harris': '17.6'}
# Données transformées : {'id': '59', 'state': 'Alabama', 'county': 'St. Clair', 'trump': 81.6, 'harris': 17.6, 'score_difference': 63.99999999999999, 'total_trump': 1994.1000000000001, 'total_harris': 975.9999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '61', 'state': 'Alabama', 'county': 'Talladega', 'trump': '66.3', 'harris': '33.0'}
# Données transformées : {'id': '61', 'state': 'Alabama', 'county': 'Talladega', 'trump': 66.3, 'harris': 33.0, 'score_difference': 33.3, 'total_trump': 2060.4, 'total_harris': 1008.9999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '63', 'state': 'Alabama', 'county': 'Tuscaloosa', 'trump': '59.5', 'harris': '39.2'}
# Données transformées : {'id': '63', 'state': 'Alabama', 'county': 'Tuscaloosa', 'trump': 59.5, 'harris': 39.2, 'score_difference': 20.299999999999997, 'total_trump': 2119.9, 'total_harris': 1048.1999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '65', 'state': 'Alabama', 'county': 'Washington', 'trump': '77.4', 'harris': '22.1'}
# Données transformées : {'id': '65', 'state': 'Alabama', 'county': 'Washington', 'trump': 77.4, 'harris': 22.1, 'score_difference': 55.300000000000004, 'total_trump': 2197.3, 'total_harris': 1070.2999999999997, 'leading_candidate': 'trump'}
# Reçu : {'id': '67', 'state': 'Alabama', 'county': 'Winston', 'trump': '91.4', 'harris': '7.9'}
# Données transformées : {'id': '67', 'state': 'Alabama', 'county': 'Winston', 'trump': 91.4, 'harris': 7.9, 'score_difference': 83.5, 'total_trump': 2288.7000000000003, 'total_harris': 1078.1999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '69', 'state': 'Alaska', 'county': 'ED02 Central/North Panhandle', 'trump': '47.5', 'harris': '47.7'}
# Données transformées : {'id': '69', 'state': 'Alaska', 'county': 'ED02 Central/North Panhandle', 'trump': 47.5, 'harris': 47.7, 'score_difference': 0.20000000000000284, 'total_trump': 47.5, 'total_harris': 47.7, 'leading_candidate': 'harris'}
# Reçu : {'id': '71', 'state': 'Alaska', 'county': 'ED04 Greater Juneau', 'trump': '29.1', 'harris': '66.4'}
# Données transformées : {'id': '71', 'state': 'Alaska', 'county': 'ED04 Greater Juneau', 'trump': 29.1, 'harris': 66.4, 'score_difference': 37.300000000000004, 'total_trump': 76.6, 'total_harris': 114.10000000000001, 'leading_candidate': 'harris'}
# Reçu : {'id': '73', 'state': 'Alaska', 'county': 'ED06 South Kenai Peninsula', 'trump': '55.3', 'harris': '40.3'}
# Données transformées : {'id': '73', 'state': 'Alaska', 'county': 'ED06 South Kenai Peninsula', 'trump': 55.3, 'harris': 40.3, 'score_difference': 15.0, 'total_trump': 131.89999999999998, 'total_harris': 154.4, 'leading_candidate': 'harris'}
# Reçu : {'id': '75', 'state': 'Alaska', 'county': 'ED08 North/East Kenai Penin.', 'trump': '73.5', 'harris': '23.9'}
# Données transformées : {'id': '75', 'state': 'Alaska', 'county': 'ED08 North/East Kenai Penin.', 'trump': 73.5, 'harris': 23.9, 'score_difference': 49.6, 'total_trump': 205.39999999999998, 'total_harris': 178.3, 'leading_candidate': 'trump'}
# Reçu : {'id': '77', 'state': 'Alaska', 'county': 'ED10 S-Central Anch Suburbs', 'trump': '50.2', 'harris': '46.1'}
# Données transformées : {'id': '77', 'state': 'Alaska', 'county': 'ED10 S-Central Anch Suburbs', 'trump': 50.2, 'harris': 46.1, 'score_difference': 4.100000000000001, 'total_trump': 255.59999999999997, 'total_harris': 224.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '79', 'state': 'Alaska', 'county': 'ED12 S-Central Anch Suburbs', 'trump': '48.0', 'harris': '48.7'}
# Données transformées : {'id': '79', 'state': 'Alaska', 'county': 'ED12 S-Central Anch Suburbs', 'trump': 48.0, 'harris': 48.7, 'score_difference': 0.7000000000000028, 'total_trump': 303.59999999999997, 'total_harris': 273.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '81', 'state': 'Alaska', 'county': 'ED14 Midtown Anchorage', 'trump': '37.5', 'harris': '58.4'}
# Données transformées : {'id': '81', 'state': 'Alaska', 'county': 'ED14 Midtown Anchorage', 'trump': 37.5, 'harris': 58.4, 'score_difference': 20.9, 'total_trump': 341.09999999999997, 'total_harris': 331.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '83', 'state': 'Alaska', 'county': 'ED16 West Anchorage Suburbs', 'trump': '40.8', 'harris': '55.1'}
# Données transformées : {'id': '83', 'state': 'Alaska', 'county': 'ED16 West Anchorage Suburbs', 'trump': 40.8, 'harris': 55.1, 'score_difference': 14.300000000000004, 'total_trump': 381.9, 'total_harris': 386.6, 'leading_candidate': 'harris'}
# Reçu : {'id': '85', 'state': 'Alaska', 'county': 'ED18 NE Anchorage City', 'trump': '56.0', 'harris': '39.9'}
# Données transformées : {'id': '85', 'state': 'Alaska', 'county': 'ED18 NE Anchorage City', 'trump': 56.0, 'harris': 39.9, 'score_difference': 16.1, 'total_trump': 437.9, 'total_harris': 426.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '87', 'state': 'Alaska', 'county': 'ED20 E-Central Anch City', 'trump': '41.9', 'harris': '53.9'}
# Données transformées : {'id': '87', 'state': 'Alaska', 'county': 'ED20 E-Central Anch City', 'trump': 41.9, 'harris': 53.9, 'score_difference': 12.0, 'total_trump': 479.79999999999995, 'total_harris': 480.4, 'leading_candidate': 'harris'}
# Reçu : {'id': '89', 'state': 'Alaska', 'county': 'ED22 NE Anchorage City', 'trump': '48.0', 'harris': '48.3'}
# Données transformées : {'id': '89', 'state': 'Alaska', 'county': 'ED22 NE Anchorage City', 'trump': 48.0, 'harris': 48.3, 'score_difference': 0.29999999999999716, 'total_trump': 527.8, 'total_harris': 528.6999999999999, 'leading_candidate': 'harris'}
# Reçu : {'id': '91', 'state': 'Alaska', 'county': 'ED24 FarNorth Anchorage Boro', 'trump': '64.3', 'harris': '31.8'}
# Données transformées : {'id': '91', 'state': 'Alaska', 'county': 'ED24 FarNorth Anchorage Boro', 'trump': 64.3, 'harris': 31.8, 'score_difference': 32.5, 'total_trump': 592.0999999999999, 'total_harris': 560.4999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '93', 'state': 'Alaska', 'county': 'ED26 Mat-Su Valley South', 'trump': '75.6', 'harris': '21.3'}
# Données transformées : {'id': '93', 'state': 'Alaska', 'county': 'ED26 Mat-Su Valley South', 'trump': 75.6, 'harris': 21.3, 'score_difference': 54.3, 'total_trump': 667.6999999999999, 'total_harris': 581.7999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '95', 'state': 'Alaska', 'county': 'ED28 Mat-Su - East Wasilla', 'trump': '72.2', 'harris': '24.0'}
# Données transformées : {'id': '95', 'state': 'Alaska', 'county': 'ED28 Mat-Su - East Wasilla', 'trump': 72.2, 'harris': 24.0, 'score_difference': 48.2, 'total_trump': 739.9, 'total_harris': 605.7999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '97', 'state': 'Alaska', 'county': 'ED30 Mat-Su - Parks Highway', 'trump': '70.8', 'harris': '26.4'}
# Données transformées : {'id': '97', 'state': 'Alaska', 'county': 'ED30 Mat-Su - Parks Highway', 'trump': 70.8, 'harris': 26.4, 'score_difference': 44.4, 'total_trump': 810.6999999999999, 'total_harris': 632.1999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '99', 'state': 'Alaska', 'county': 'ED32 East Fairbanks', 'trump': '63.8', 'harris': '32.1'}
# Données transformées : {'id': '99', 'state': 'Alaska', 'county': 'ED32 East Fairbanks', 'trump': 63.8, 'harris': 32.1, 'score_difference': 31.699999999999996, 'total_trump': 874.4999999999999, 'total_harris': 664.2999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '101', 'state': 'Alaska', 'county': 'ED34 E. Fairbanks Outskirts', 'trump': '58.3', 'harris': '37.5'}
# Données transformées : {'id': '101', 'state': 'Alaska', 'county': 'ED34 E. Fairbanks Outskirts', 'trump': 58.3, 'harris': 37.5, 'score_difference': 20.799999999999997, 'total_trump': 932.7999999999998, 'total_harris': 701.7999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '103', 'state': 'Alaska', 'county': 'ED36 Interior Alaska', 'trump': '58.8', 'harris': '36.8'}
# Données transformées : {'id': '103', 'state': 'Alaska', 'county': 'ED36 Interior Alaska', 'trump': 58.8, 'harris': 36.8, 'score_difference': 22.0, 'total_trump': 991.5999999999998, 'total_harris': 738.5999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '105', 'state': 'Alaska', 'county': 'ED38 Bering Coast', 'trump': '37.0', 'harris': '50.6'}
# Données transformées : {'id': '105', 'state': 'Alaska', 'county': 'ED38 Bering Coast', 'trump': 37.0, 'harris': 50.6, 'score_difference': 13.600000000000001, 'total_trump': 1028.6, 'total_harris': 789.1999999999998, 'leading_candidate': 'trump'}
# Reçu : {'id': '107', 'state': 'Alaska', 'county': 'ED40 Arctic', 'trump': '50.2', 'harris': '42.2'}
# Données transformées : {'id': '107', 'state': 'Alaska', 'county': 'ED40 Arctic', 'trump': 50.2, 'harris': 42.2, 'score_difference': 8.0, 'total_trump': 1078.8, 'total_harris': 831.3999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '109', 'state': 'Arizona', 'county': 'Cochise', 'trump': '61.0', 'harris': '37.8'}
# Données transformées : {'id': '109', 'state': 'Arizona', 'county': 'Cochise', 'trump': 61.0, 'harris': 37.8, 'score_difference': 23.200000000000003, 'total_trump': 61.0, 'total_harris': 37.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '111', 'state': 'Arizona', 'county': 'Gila', 'trump': '68.4', 'harris': '30.8'}
# Données transformées : {'id': '111', 'state': 'Arizona', 'county': 'Gila', 'trump': 68.4, 'harris': 30.8, 'score_difference': 37.60000000000001, 'total_trump': 129.4, 'total_harris': 68.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '113', 'state': 'Arizona', 'county': 'Greenlee', 'trump': '69.8', 'harris': '28.8'}
# Données transformées : {'id': '113', 'state': 'Arizona', 'county': 'Greenlee', 'trump': 69.8, 'harris': 28.8, 'score_difference': 41.0, 'total_trump': 199.2, 'total_harris': 97.39999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '115', 'state': 'Arizona', 'county': 'Maricopa', 'trump': '51.2', 'harris': '47.7'}
# Données transformées : {'id': '115', 'state': 'Arizona', 'county': 'Maricopa', 'trump': 51.2, 'harris': 47.7, 'score_difference': 3.5, 'total_trump': 250.39999999999998, 'total_harris': 145.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '117', 'state': 'Arizona', 'county': 'Navajo', 'trump': '58.1', 'harris': '40.9'}
# Données transformées : {'id': '117', 'state': 'Arizona', 'county': 'Navajo', 'trump': 58.1, 'harris': 40.9, 'score_difference': 17.200000000000003, 'total_trump': 308.5, 'total_harris': 186.0, 'leading_candidate': 'trump'}
# Reçu : {'id': '119', 'state': 'Arizona', 'county': 'Pinal', 'trump': '60.6', 'harris': '38.5'}
# Données transformées : {'id': '119', 'state': 'Arizona', 'county': 'Pinal', 'trump': 60.6, 'harris': 38.5, 'score_difference': 22.1, 'total_trump': 369.1, 'total_harris': 224.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '121', 'state': 'Arizona', 'county': 'Yavapai', 'trump': '66.5', 'harris': '32.6'}
# Données transformées : {'id': '121', 'state': 'Arizona', 'county': 'Yavapai', 'trump': 66.5, 'harris': 32.6, 'score_difference': 33.9, 'total_trump': 435.6, 'total_harris': 257.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '123', 'state': 'Arkansas', 'county': 'Arkansas County', 'trump': '71.2', 'harris': '27.1'}
# Données transformées : {'id': '123', 'state': 'Arkansas', 'county': 'Arkansas County', 'trump': 71.2, 'harris': 27.1, 'score_difference': 44.1, 'total_trump': 71.2, 'total_harris': 27.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '125', 'state': 'Arkansas', 'county': 'Baxter', 'trump': '77.6', 'harris': '20.7'}
# Données transformées : {'id': '125', 'state': 'Arkansas', 'county': 'Baxter', 'trump': 77.6, 'harris': 20.7, 'score_difference': 56.89999999999999, 'total_trump': 148.8, 'total_harris': 47.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '127', 'state': 'Arkansas', 'county': 'Boone', 'trump': '81.6', 'harris': '16.7'}
# Données transformées : {'id': '127', 'state': 'Arkansas', 'county': 'Boone', 'trump': 81.6, 'harris': 16.7, 'score_difference': 64.89999999999999, 'total_trump': 230.4, 'total_harris': 64.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '129', 'state': 'Arkansas', 'county': 'Calhoun', 'trump': '80.0', 'harris': '18.1'}
# Données transformées : {'id': '129', 'state': 'Arkansas', 'county': 'Calhoun', 'trump': 80.0, 'harris': 18.1, 'score_difference': 61.9, 'total_trump': 310.4, 'total_harris': 82.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '131', 'state': 'Arkansas', 'county': 'Chicot', 'trump': '47.5', 'harris': '51.5'}
# Données transformées : {'id': '131', 'state': 'Arkansas', 'county': 'Chicot', 'trump': 47.5, 'harris': 51.5, 'score_difference': 4.0, 'total_trump': 357.9, 'total_harris': 134.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '133', 'state': 'Arkansas', 'county': 'Clay', 'trump': '79.9', 'harris': '18.3'}
# Données transformées : {'id': '133', 'state': 'Arkansas', 'county': 'Clay', 'trump': 79.9, 'harris': 18.3, 'score_difference': 61.60000000000001, 'total_trump': 437.79999999999995, 'total_harris': 152.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '135', 'state': 'Arkansas', 'county': 'Cleveland', 'trump': '83.1', 'harris': '15.5'}
# Données transformées : {'id': '135', 'state': 'Arkansas', 'county': 'Cleveland', 'trump': 83.1, 'harris': 15.5, 'score_difference': 67.6, 'total_trump': 520.9, 'total_harris': 167.9, 'leading_candidate': 'trump'}
# Reçu : {'id': '137', 'state': 'Arkansas', 'county': 'Conway', 'trump': '69.0', 'harris': '28.7'}
# Données transformées : {'id': '137', 'state': 'Arkansas', 'county': 'Conway', 'trump': 69.0, 'harris': 28.7, 'score_difference': 40.3, 'total_trump': 589.9, 'total_harris': 196.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '139', 'state': 'Arkansas', 'county': 'Crawford', 'trump': '78.1', 'harris': '19.9'}
# Données transformées : {'id': '139', 'state': 'Arkansas', 'county': 'Crawford', 'trump': 78.1, 'harris': 19.9, 'score_difference': 58.199999999999996, 'total_trump': 668.0, 'total_harris': 216.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '141', 'state': 'Arkansas', 'county': 'Cross', 'trump': '72.7', 'harris': '25.1'}
# Données transformées : {'id': '141', 'state': 'Arkansas', 'county': 'Cross', 'trump': 72.7, 'harris': 25.1, 'score_difference': 47.6, 'total_trump': 740.7, 'total_harris': 241.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '143', 'state': 'Arkansas', 'county': 'Desha', 'trump': '51.5', 'harris': '46.7'}
# Données transformées : {'id': '143', 'state': 'Arkansas', 'county': 'Desha', 'trump': 51.5, 'harris': 46.7, 'score_difference': 4.799999999999997, 'total_trump': 792.2, 'total_harris': 288.3, 'leading_candidate': 'trump'}
# Reçu : {'id': '145', 'state': 'Arkansas', 'county': 'Faulkner', 'trump': '64.9', 'harris': '32.6'}
# Données transformées : {'id': '145', 'state': 'Arkansas', 'county': 'Faulkner', 'trump': 64.9, 'harris': 32.6, 'score_difference': 32.300000000000004, 'total_trump': 857.1, 'total_harris': 320.90000000000003, 'leading_candidate': 'trump'}
# Reçu : {'id': '147', 'state': 'Arkansas', 'county': 'Fulton', 'trump': '80.1', 'harris': '18.0'}
# Données transformées : {'id': '147', 'state': 'Arkansas', 'county': 'Fulton', 'trump': 80.1, 'harris': 18.0, 'score_difference': 62.099999999999994, 'total_trump': 937.2, 'total_harris': 338.90000000000003, 'leading_candidate': 'trump'}
# Reçu : {'id': '149', 'state': 'Arkansas', 'county': 'Grant', 'trump': '83.6', 'harris': '14.8'}
# Données transformées : {'id': '149', 'state': 'Arkansas', 'county': 'Grant', 'trump': 83.6, 'harris': 14.8, 'score_difference': 68.8, 'total_trump': 1020.8000000000001, 'total_harris': 353.70000000000005, 'leading_candidate': 'trump'}
# Reçu : {'id': '151', 'state': 'Arkansas', 'county': 'Hempstead', 'trump': '68.9', 'harris': '29.2'}
# Données transformées : {'id': '151', 'state': 'Arkansas', 'county': 'Hempstead', 'trump': 68.9, 'harris': 29.2, 'score_difference': 39.7, 'total_trump': 1089.7, 'total_harris': 382.90000000000003, 'leading_candidate': 'trump'}
# Reçu : {'id': '153', 'state': 'Arkansas', 'county': 'Howard', 'trump': '72.6', 'harris': '25.9'}
# Données transformées : {'id': '153', 'state': 'Arkansas', 'county': 'Howard', 'trump': 72.6, 'harris': 25.9, 'score_difference': 46.699999999999996, 'total_trump': 1162.3, 'total_harris': 408.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '155', 'state': 'Arkansas', 'county': 'Izard', 'trump': '81.9', 'harris': '16.0'}
# Données transformées : {'id': '155', 'state': 'Arkansas', 'county': 'Izard', 'trump': 81.9, 'harris': 16.0, 'score_difference': 65.9, 'total_trump': 1244.2, 'total_harris': 424.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '157', 'state': 'Arkansas', 'county': 'Jefferson', 'trump': '39.2', 'harris': '59.2'}
# Données transformées : {'id': '157', 'state': 'Arkansas', 'county': 'Jefferson', 'trump': 39.2, 'harris': 59.2, 'score_difference': 20.0, 'total_trump': 1283.4, 'total_harris': 484.0, 'leading_candidate': 'trump'}
# Reçu : {'id': '159', 'state': 'Arkansas', 'county': 'Lafayette', 'trump': '68.3', 'harris': '30.0'}
# Données transformées : {'id': '159', 'state': 'Arkansas', 'county': 'Lafayette', 'trump': 68.3, 'harris': 30.0, 'score_difference': 38.3, 'total_trump': 1351.7, 'total_harris': 514.0, 'leading_candidate': 'trump'}
# Reçu : {'id': '161', 'state': 'Arkansas', 'county': 'Lee', 'trump': '46.9', 'harris': '50.4'}
# Données transformées : {'id': '161', 'state': 'Arkansas', 'county': 'Lee', 'trump': 46.9, 'harris': 50.4, 'score_difference': 3.5, 'total_trump': 1398.6000000000001, 'total_harris': 564.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '163', 'state': 'Arkansas', 'county': 'Little River', 'trump': '76.4', 'harris': '22.1'}
# Données transformées : {'id': '163', 'state': 'Arkansas', 'county': 'Little River', 'trump': 76.4, 'harris': 22.1, 'score_difference': 54.300000000000004, 'total_trump': 1475.0000000000002, 'total_harris': 586.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '165', 'state': 'Arkansas', 'county': 'Lonoke', 'trump': '75.8', 'harris': '22.2'}
# Données transformées : {'id': '165', 'state': 'Arkansas', 'county': 'Lonoke', 'trump': 75.8, 'harris': 22.2, 'score_difference': 53.599999999999994, 'total_trump': 1550.8000000000002, 'total_harris': 608.7, 'leading_candidate': 'trump'}
# Reçu : {'id': '167', 'state': 'Arkansas', 'county': 'Marion', 'trump': '79.4', 'harris': '19.1'}
# Données transformées : {'id': '167', 'state': 'Arkansas', 'county': 'Marion', 'trump': 79.4, 'harris': 19.1, 'score_difference': 60.300000000000004, 'total_trump': 1630.2000000000003, 'total_harris': 627.8000000000001, 'leading_candidate': 'trump'}
# Reçu : {'id': '169', 'state': 'Arkansas', 'county': 'Mississippi', 'trump': '65.0', 'harris': '33.3'}
# Données transformées : {'id': '169', 'state': 'Arkansas', 'county': 'Mississippi', 'trump': 65.0, 'harris': 33.3, 'score_difference': 31.700000000000003, 'total_trump': 1695.2000000000003, 'total_harris': 661.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '171', 'state': 'Arkansas', 'county': 'Montgomery', 'trump': '80.6', 'harris': '17.4'}
# Données transformées : {'id': '171', 'state': 'Arkansas', 'county': 'Montgomery', 'trump': 80.6, 'harris': 17.4, 'score_difference': 63.199999999999996, 'total_trump': 1775.8000000000002, 'total_harris': 678.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '173', 'state': 'Arkansas', 'county': 'Newton', 'trump': '81.2', 'harris': '17.1'}
# Données transformées : {'id': '173', 'state': 'Arkansas', 'county': 'Newton', 'trump': 81.2, 'harris': 17.1, 'score_difference': 64.1, 'total_trump': 1857.0000000000002, 'total_harris': 695.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '175', 'state': 'Arkansas', 'county': 'Perry', 'trump': '77.6', 'harris': '20.1'}
# Données transformées : {'id': '175', 'state': 'Arkansas', 'county': 'Perry', 'trump': 77.6, 'harris': 20.1, 'score_difference': 57.49999999999999, 'total_trump': 1934.6000000000001, 'total_harris': 715.7, 'leading_candidate': 'trump'}
# Reçu : {'id': '177', 'state': 'Arkansas', 'county': 'Pike', 'trump': '86.0', 'harris': '12.8'}
# Données transformées : {'id': '177', 'state': 'Arkansas', 'county': 'Pike', 'trump': 86.0, 'harris': 12.8, 'score_difference': 73.2, 'total_trump': 2020.6000000000001, 'total_harris': 728.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '179', 'state': 'Arkansas', 'county': 'Polk', 'trump': '84.3', 'harris': '13.8'}
# Données transformées : {'id': '179', 'state': 'Arkansas', 'county': 'Polk', 'trump': 84.3, 'harris': 13.8, 'score_difference': 70.5, 'total_trump': 2104.9, 'total_harris': 742.3, 'leading_candidate': 'trump'}
# Reçu : {'id': '181', 'state': 'Arkansas', 'county': 'Prairie', 'trump': '82.1', 'harris': '16.4'}
# Données transformées : {'id': '181', 'state': 'Arkansas', 'county': 'Prairie', 'trump': 82.1, 'harris': 16.4, 'score_difference': 65.69999999999999, 'total_trump': 2187.0, 'total_harris': 758.6999999999999, 'leading_candidate': 'trump'}
# Reçu : {'id': '183', 'state': 'Arkansas', 'county': 'Randolph', 'trump': '80.9', 'harris': '17.1'}
# Données transformées : {'id': '183', 'state': 'Arkansas', 'county': 'Randolph', 'trump': 80.9, 'harris': 17.1, 'score_difference': 63.800000000000004, 'total_trump': 2267.9, 'total_harris': 775.8, 'leading_candidate': 'trump'}
# Reçu : {'id': '185', 'state': 'Arkansas', 'county': 'Scott', 'trump': '86.1', 'harris': '12.6'}
# Données transformées : {'id': '185', 'state': 'Arkansas', 'county': 'Scott', 'trump': 86.1, 'harris': 12.6, 'score_difference': 73.5, 'total_trump': 2354.0, 'total_harris': 788.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '187', 'state': 'Arkansas', 'county': 'Sebastian', 'trump': '67.6', 'harris': '30.0'}
# Données transformées : {'id': '187', 'state': 'Arkansas', 'county': 'Sebastian', 'trump': 67.6, 'harris': 30.0, 'score_difference': 37.599999999999994, 'total_trump': 2421.6, 'total_harris': 818.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '189', 'state': 'Arkansas', 'county': 'Sharp', 'trump': '80.4', 'harris': '17.7'}
# Données transformées : {'id': '189', 'state': 'Arkansas', 'county': 'Sharp', 'trump': 80.4, 'harris': 17.7, 'score_difference': 62.7, 'total_trump': 2502.0, 'total_harris': 836.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '191', 'state': 'Arkansas', 'county': 'Stone', 'trump': '79.7', 'harris': '18.1'}
# Données transformées : {'id': '191', 'state': 'Arkansas', 'county': 'Stone', 'trump': 79.7, 'harris': 18.1, 'score_difference': 61.6, 'total_trump': 2581.7, 'total_harris': 854.2, 'leading_candidate': 'trump'}
# Reçu : {'id': '193', 'state': 'Arkansas', 'county': 'Van Buren', 'trump': '79.0', 'harris': '18.9'}
# Données transformées : {'id': '193', 'state': 'Arkansas', 'county': 'Van Buren', 'trump': 79.0, 'harris': 18.9, 'score_difference': 60.1, 'total_trump': 2660.7, 'total_harris': 873.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '195', 'state': 'Arkansas', 'county': 'White', 'trump': '79.5', 'harris': '18.3'}
# Données transformées : {'id': '195', 'state': 'Arkansas', 'county': 'White', 'trump': 79.5, 'harris': 18.3, 'score_difference': 61.2, 'total_trump': 2740.2, 'total_harris': 891.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '197', 'state': 'Arkansas', 'county': 'Yell', 'trump': '79.5', 'harris': '18.7'}
# Données transformées : {'id': '197', 'state': 'Arkansas', 'county': 'Yell', 'trump': 79.5, 'harris': 18.7, 'score_difference': 60.8, 'total_trump': 2819.7, 'total_harris': 910.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '199', 'state': 'California', 'county': 'Alpine', 'trump': '32.9', 'harris': '64.9'}
# Données transformées : {'id': '199', 'state': 'California', 'county': 'Alpine', 'trump': 32.9, 'harris': 64.9, 'score_difference': 32.00000000000001, 'total_trump': 32.9, 'total_harris': 64.9, 'leading_candidate': 'harris'}
# Reçu : {'id': '201', 'state': 'California', 'county': 'Butte', 'trump': '49.9', 'harris': '46.8'}
# Données transformées : {'id': '201', 'state': 'California', 'county': 'Butte', 'trump': 49.9, 'harris': 46.8, 'score_difference': 3.1000000000000014, 'total_trump': 82.8, 'total_harris': 111.7, 'leading_candidate': 'harris'}
# Reçu : {'id': '203', 'state': 'California', 'county': 'Colusa', 'trump': '62.9', 'harris': '34.6'}
# Données transformées : {'id': '203', 'state': 'California', 'county': 'Colusa', 'trump': 62.9, 'harris': 34.6, 'score_difference': 28.299999999999997, 'total_trump': 145.7, 'total_harris': 146.3, 'leading_candidate': 'harris'}
# Reçu : {'id': '205', 'state': 'California', 'county': 'Del Norte', 'trump': '56.8', 'harris': '40.4'}
# Données transformées : {'id': '205', 'state': 'California', 'county': 'Del Norte', 'trump': 56.8, 'harris': 40.4, 'score_difference': 16.4, 'total_trump': 202.5, 'total_harris': 186.70000000000002, 'leading_candidate': 'trump'}
# Reçu : {'id': '207', 'state': 'California', 'county': 'Fresno', 'trump': '51.0', 'harris': '46.5'}
# Données transformées : {'id': '207', 'state': 'California', 'county': 'Fresno', 'trump': 51.0, 'harris': 46.5, 'score_difference': 4.5, 'total_trump': 253.5, 'total_harris': 233.20000000000002, 'leading_candidate': 'trump'}
# Reçu : {'id': '209', 'state': 'California', 'county': 'Humboldt', 'trump': '33.5', 'harris': '62.0'}
# Données transformées : {'id': '209', 'state': 'California', 'county': 'Humboldt', 'trump': 33.5, 'harris': 62.0, 'score_difference': 28.5, 'total_trump': 287.0, 'total_harris': 295.20000000000005, 'leading_candidate': 'harris'}
# Reçu : {'id': '211', 'state': 'California', 'county': 'Inyo', 'trump': '49.9', 'harris': '46.9'}
# Données transformées : {'id': '211', 'state': 'California', 'county': 'Inyo', 'trump': 49.9, 'harris': 46.9, 'score_difference': 3.0, 'total_trump': 336.9, 'total_harris': 342.1, 'leading_candidate': 'harris'}
# Reçu : {'id': '213', 'state': 'California', 'county': 'Kings', 'trump': '60.4', 'harris': '37.4'}
# Données transformées : {'id': '213', 'state': 'California', 'county': 'Kings', 'trump': 60.4, 'harris': 37.4, 'score_difference': 23.0, 'total_trump': 397.29999999999995, 'total_harris': 379.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '215', 'state': 'California', 'county': 'Lassen', 'trump': '75.7', 'harris': '21.9'}
# Données transformées : {'id': '215', 'state': 'California', 'county': 'Lassen', 'trump': 75.7, 'harris': 21.9, 'score_difference': 53.800000000000004, 'total_trump': 472.99999999999994, 'total_harris': 401.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '217', 'state': 'California', 'county': 'Madera', 'trump': '59.2', 'harris': '38.4'}
# Données transformées : {'id': '217', 'state': 'California', 'county': 'Madera', 'trump': 59.2, 'harris': 38.4, 'score_difference': 20.800000000000004, 'total_trump': 532.1999999999999, 'total_harris': 439.79999999999995, 'leading_candidate': 'trump'}
# Reçu : {'id': '219', 'state': 'California', 'county': 'Mariposa', 'trump': '59.2', 'harris': '38.1'}
# Données transformées : {'id': '219', 'state': 'California', 'county': 'Mariposa', 'trump': 59.2, 'harris': 38.1, 'score_difference': 21.1, 'total_trump': 591.4, 'total_harris': 477.9, 'leading_candidate': 'trump'}
# Reçu : {'id': '221', 'state': 'California', 'county': 'Merced', 'trump': '50.8', 'harris': '46.6'}
# Données transformées : {'id': '221', 'state': 'California', 'county': 'Merced', 'trump': 50.8, 'harris': 46.6, 'score_difference': 4.199999999999996, 'total_trump': 642.1999999999999, 'total_harris': 524.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '223', 'state': 'California', 'county': 'Mono', 'trump': '37.8', 'harris': '58.1'}
# Données transformées : {'id': '223', 'state': 'California', 'county': 'Mono', 'trump': 37.8, 'harris': 58.1, 'score_difference': 20.300000000000004, 'total_trump': 679.9999999999999, 'total_harris': 582.6, 'leading_candidate': 'trump'}
# Reçu : {'id': '225', 'state': 'California', 'county': 'Napa', 'trump': '31.1', 'harris': '65.9'}
# Données transformées : {'id': '225', 'state': 'California', 'county': 'Napa', 'trump': 31.1, 'harris': 65.9, 'score_difference': 34.800000000000004, 'total_trump': 711.0999999999999, 'total_harris': 648.5, 'leading_candidate': 'trump'}
# Reçu : {'id': '227', 'state': 'California', 'county': 'Orange', 'trump': '47.1', 'harris': '49.7'}
# Données transformées : {'id': '227', 'state': 'California', 'county': 'Orange', 'trump': 47.1, 'harris': 49.7, 'score_difference': 2.6000000000000014, 'total_trump': 758.1999999999999, 'total_harris': 698.2, 'leading_candidate': 'trump'}
# Reçu : {'id': '229', 'state': 'California', 'county': 'Plumas', 'trump': '56.9', 'harris': '39.9'}
# Données transformées : {'id': '229', 'state': 'California', 'county': 'Plumas', 'trump': 56.9, 'harris': 39.9, 'score_difference': 17.0, 'total_trump': 815.0999999999999, 'total_harris': 738.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '231', 'state': 'California', 'county': 'Sacramento', 'trump': '38.3', 'harris': '58.2'}
# Données transformées : {'id': '231', 'state': 'California', 'county': 'Sacramento', 'trump': 38.3, 'harris': 58.2, 'score_difference': 19.900000000000006, 'total_trump': 853.3999999999999, 'total_harris': 796.3000000000001, 'leading_candidate': 'trump'}
# Reçu : {'id': '233', 'state': 'California', 'county': 'San Bernardino', 'trump': '49.7', 'harris': '47.5'}
# Données transformées : {'id': '233', 'state': 'California', 'county': 'San Bernardino', 'trump': 49.7, 'harris': 47.5, 'score_difference': 2.200000000000003, 'total_trump': 903.0999999999999, 'total_harris': 843.8000000000001, 'leading_candidate': 'trump'}
# Reçu : {'id': '235', 'state': 'California', 'county': 'San Francisco', 'trump': '15.5', 'harris': '80.3'}
# Données transformées : {'id': '235', 'state': 'California', 'county': 'San Francisco', 'trump': 15.5, 'harris': 80.3, 'score_difference': 64.8, 'total_trump': 918.5999999999999, 'total_harris': 924.1, 'leading_candidate': 'harris'}
# Reçu : {'id': '237', 'state': 'California', 'county': 'San Luis Obispo', 'trump': '43.1', 'harris': '53.9'}
# Données transformées : {'id': '237', 'state': 'California', 'county': 'San Luis Obispo', 'trump': 43.1, 'harris': 53.9, 'score_difference': 10.799999999999997, 'total_trump': 961.6999999999999, 'total_harris': 978.0, 'leading_candidate': 'harris'}
# Reçu : {'id': '239', 'state': 'California', 'county': 'Santa Barbara', 'trump': '35.1', 'harris': '61.8'}
# Données transformées : {'id': '239', 'state': 'California', 'county': 'Santa Barbara', 'trump': 35.1, 'harris': 61.8, 'score_difference': 26.699999999999996, 'total_trump': 996.8, 'total_harris': 1039.8, 'leading_candidate': 'harris'}
# Reçu : {'id': '241', 'state': 'California', 'county': 'Santa Cruz', 'trump': '20.9', 'harris': '75.2'}
# Données transformées : {'id': '241', 'state': 'California', 'county': 'Santa Cruz', 'trump': 20.9, 'harris': 75.2, 'score_difference': 54.300000000000004, 'total_trump': 1017.6999999999999, 'total_harris': 1115.0, 'leading_candidate': 'harris'}
# Reçu : {'id': '243', 'state': 'California', 'county': 'Sierra', 'trump': '60.8', 'harris': '36.5'}
# Données transformées : {'id': '243', 'state': 'California', 'county': 'Sierra', 'trump': 60.8, 'harris': 36.5, 'score_difference': 24.299999999999997, 'total_trump': 1078.5, 'total_harris': 1151.5, 'leading_candidate': 'harris'}
# Reçu : {'id': '245', 'state': 'California', 'county': 'Solano', 'trump': '37.1', 'harris': '60.0'}
# Données transformées : {'id': '245', 'state': 'California', 'county': 'Solano', 'trump': 37.1, 'harris': 60.0, 'score_difference': 22.9, 'total_trump': 1115.6, 'total_harris': 1211.5, 'leading_candidate': 'harris'}
# Reçu : {'id': '247', 'state': 'California', 'county': 'Stanislaus', 'trump': '54.2', 'harris': '43.2'}
# Données transformées : {'id': '247', 'state': 'California', 'county': 'Stanislaus', 'trump': 54.2, 'harris': 43.2, 'score_difference': 11.0, 'total_trump': 1169.8, 'total_harris': 1254.7, 'leading_candidate': 'harris'}
# Reçu : {'id': '249', 'state': 'California', 'county': 'Tehama', 'trump': '69.7', 'harris': '28.0'}
# Données transformées : {'id': '249', 'state': 'California', 'county': 'Tehama', 'trump': 69.7, 'harris': 28.0, 'score_difference': 41.7, 'total_trump': 1239.5, 'total_harris': 1282.7, 'leading_candidate': 'harris'}
# Reçu : {'id': '251', 'state': 'California', 'county': 'Tulare', 'trump': '59.2', 'harris': '38.5'}
# Données transformées : {'id': '251', 'state': 'California', 'county': 'Tulare', 'trump': 59.2, 'harris': 38.5, 'score_difference': 20.700000000000003, 'total_trump': 1298.7, 'total_harris': 1321.2, 'leading_candidate': 'harris'}
# Reçu : {'id': '253', 'state': 'California', 'county': 'Ventura', 'trump': '41.0', 'harris': '56.1'}
# Données transformées : {'id': '253', 'state': 'California', 'county': 'Ventura', 'trump': 41.0, 'harris': 56.1, 'score_difference': 15.100000000000001, 'total_trump': 1339.7, 'total_harris': 1377.3, 'leading_candidate': 'harris'}
# Reçu : {'id': '255', 'state': 'California', 'county': 'Yuba', 'trump': '61.5', 'harris': '35.7'}
# Données transformées : {'id': '255', 'state': 'California', 'county': 'Yuba', 'trump': 61.5, 'harris': 35.7, 'score_difference': 25.799999999999997, 'total_trump': 1401.2, 'total_harris': 1413.0, 'leading_candidate': 'harris'}
# Reçu : {'id': '257', 'state': 'Colorado', 'county': 'Alamosa', 'trump': '54.0', 'harris': '43.1'}
# Données transformées : {'id': '257', 'state': 'Colorado', 'county': 'Alamosa', 'trump': 54.0, 'harris': 43.1, 'score_difference': 10.899999999999999, 'total_trump': 54.0, 'total_harris': 43.1, 'leading_candidate': 'trump'}
# Reçu : {'id': '259', 'state': 'Colorado', 'county': 'Archuleta', 'trump': '55.8', 'harris': '41.7'}
# Données transformées : {'id': '259', 'state': 'Colorado', 'county': 'Archuleta', 'trump': 55.8, 'harris': 41.7, 'score_difference': 14.099999999999994, 'total_trump': 109.8, 'total_harris': 84.80000000000001, 'leading_candidate': 'trump'}
# Reçu : {'id': '261', 'state': 'Colorado', 'county': 'Bent', 'trump': '68.3', 'harris': '29.5'}
# Données transformées : {'id': '261', 'state': 'Colorado', 'county': 'Bent', 'trump': 68.3, 'harris': 29.5, 'score_difference': 38.8, 'total_trump': 178.1, 'total_harris': 114.30000000000001, 'leading_candidate': 'trump'}
# Reçu : {'id': '263', 'state': 'Colorado', 'county': 'Broomfield', 'trump': '34.3', 'harris': '62.9'}
# Données transformées : {'id': '263', 'state': 'Colorado', 'county': 'Broomfield', 'trump': 34.3, 'harris': 62.9, 'score_difference': 28.6, 'total_trump': 212.39999999999998, 'total_harris': 177.20000000000002, 'leading_candidate': 'trump'}
# Reçu : {'id': '265', 'state': 'Colorado', 'county': 'Cheyenne', 'trump': '88.2', 'harris': '10.2'}
# Données transformées : {'id': '265', 'state': 'Colorado', 'county': 'Cheyenne', 'trump': 88.2, 'harris': 10.2, 'score_difference': 78.0, 'total_trump': 300.59999999999997, 'total_harris': 187.4, 'leading_candidate': 'trump'}
# Reçu : {'id': '267', 'state': 'Colorado', 'county': 'Conejos', 'trump': '57.5', 'harris': '39.6'}
# Données transformées : {'id': '267', 'state': 'Colorado', 'county': 'Conejos', 'trump': 57.5, 'harris': 39.6, 'score_difference': 17.9, 'total_trump': 358.09999999999997, 'total_harris': 227.0, 'leading_candidate': 'trump'}
# Reçu : {'id': '269', 'state': 'Colorado', 'county': 'Crowley', 'trump': '72.2', 'harris': '24.7'}
# Données transformées : {'id': '269', 'state': 'Colorado', 'county': 'Crowley', 'trump': 72.2, 'harris': 24.7, 'score_difference': 47.5, 'total_trump': 430.29999999999995, 'total_harris': 251.7, 'leading_candidate': 'trump'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      25 state_aggregation = {}
#      27 # Traitement des messages reçus
# ---> 28 for message in consumer:
#      29     data = message.value
#      30     print(f"Reçu : {data}")
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /opt/conda/lib/python3.11/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.11/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
